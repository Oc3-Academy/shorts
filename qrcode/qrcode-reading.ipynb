# %%
from pyzbar.pyzbar import decode
from PIL import Image

# %%
img = Image.open("data/qrcode-oc3.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=1 size=430x430>

# %%
data = decode(img)
# Out:
# [Decoded(data=b'https://www.youtube.com/channel/UCBQhHragJQAbenC3iBIOJ5Q', type='QRCODE', rect=Rect(left=50, top=50, width=330, height=330), polygon=[Point(x=50, y=50), Point(x=50, y=379), Point(x=380, y=380), Point(x=379, y=50)], quality=1, orientation='UP')]

# %%
data[0].data.decode("utf-8")
# Out:
# 'https://www.youtube.com/channel/UCBQhHragJQAbenC3iBIOJ5Q'

# %%
# rect = blue, polygon = pink
Image.open("data/qrcode-examples.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=788x735>

# %%
data[0].data
# Out:
# b'https://www.youtube.com/channel/UCBQhHragJQAbenC3iBIOJ5Q'
