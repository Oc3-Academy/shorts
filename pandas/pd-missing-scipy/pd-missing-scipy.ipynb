# %%
import pandas as pd
import seaborn as sns
import scipy

# %%
pg_df = sns.load_dataset("penguins")
pg_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
pg_df.interpolate(method="nearest")
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
## Métodos disponíveis para lidar com os missings
methods = {
    "method": [
        "linear",
        "time",
        "value/index",
        "nearest",
        "zero",
        "slinear",
        "quadratic",
        "cubic",
        "polynomial",
        "spline",
        "barycentric",
        "krogh",
        "piecewise_polynomial",
        "pchip"
    ],
    "effect": [
        "Trata o valores como igualmente espaçados",
        "Preenche valores se baseando no 'time index'",
        "Utiliza o index",
        "Usa o ponto mais próximo",
        "Usa o último ponto visto",
        "Interpolação spline de primeira ordem",
        "Interpolação spline de segunda ordem",
        "Interpolação spline de terceira ordem",
        "Interpolação polinomial",
        "Interpolação spline (passa a ordem)",
        "Usa a interpolação Barycentric Lagrande",
        "Usa interpolação Krogh",
        "Usa interpolação Piecewise Polynomial",
        "Usa interpolação Piecewise CUbic Hermite Polynomial"
    ]
}

pd.DataFrame(methods)
# Out:
#                   method                                             effect
# 0                 linear          Trata o valores como igualmente espaçados
# 1                   time       Preenche valores se baseando no 'time index'
# 2            value/index                                    Utiliza o index
# 3                nearest                           Usa o ponto mais próximo
# 4                   zero                           Usa o último ponto visto
# 5                slinear              Interpolação spline de primeira ordem
# 6              quadratic               Interpolação spline de segunda ordem
# 7                  cubic              Interpolação spline de terceira ordem
# 8             polynomial                            Interpolação polinomial
# 9                 spline                Interpolação spline (passa a ordem)
# 10           barycentric            Usa a interpolação Barycentric Lagrande
# ...
